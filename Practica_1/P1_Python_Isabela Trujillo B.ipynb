# %% [markdown]
# #### Práctica 1
# Isabela Trujillo Betancourt

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from pandas import Series

# %% [markdown]
# a) Crear el siguiente par de vectores:
# a = [67.1,1, -0.3, 5.2, -6], b= [1, 3, 2.2, 5.1, 1]

# %%
a = np.array([67.1, 1, -0.3, 5.2, -6])
b = np.array([1, 3, 2.2, 5.1, 1])
print(a)
print(b)
# Out:
# [67.1  1.  -0.3  5.2 -6. ]
# [1.  3.  2.2 5.1 1. ]

# %% [markdown]
# b) Implemente la multiplicación escalar de a.b ¿Qué se debe realizar para poder multiplicar los dos vectores?

# %%
prod_esc = np.dot(a,b) # Se puede usar el comando dot
prod_esc_2 = np.sum(a*b) # La otra opción es multiplicar los elementos y luego sumarlos
print("Producto escalar por el método 1: ", prod_esc)
print("Producto escalar por el método 2: ", prod_esc_2)
# Out:
# Producto escalar por el método 1:  89.96
# Producto escalar por el método 2:  89.96

# %% [markdown]
# c) Implemente la multiplicación punto a punto de a.b

# %%
prod_punto = a*b
print(prod_punto)
# Out:
# [67.1   3.   -0.66 26.52 -6.  ]

# %% [markdown]
# d) Construya la siguiente matriz:
# 𝐴=[2 −1 −3; 4 −1.5 −2.5; 7.3 −0.9 −0.2]

# %%
A = np.array([[2, -1, -3], [4, -1.5, -2.5],[7.3, -0.9, -0.2]])
A
# Out:
# array([[ 2. , -1. , -3. ],
#        [ 4. , -1.5, -2.5],
#        [ 7.3, -0.9, -0.2]])

# %% [markdown]
# e) Obtenga su transpuesta AT.

# %%
transpuesta = A.T
transpuesta
# Out:
# array([[ 2. ,  4. ,  7.3],
#        [-1. , -1.5, -0.9],
#        [-3. , -2.5, -0.2]])

# %% [markdown]
# f) Consulte la función de los siguientes comandos de la librería numpy: ones, round, ceil, floor, implemente cada función para ejemplificar su uso

# %%
one = np.ones((3,2)) # Genera un array con las dimensiones espécificadas cuyos elementos todos son unos
redondeo = np.round(16.03459,3) # Redondea un valor con las cifras decimales especificadas
red_arr = np.ceil(16.03459) # Redondea el valor entero hacia arriba
red_aba = np.floor(16.03459) # Redondea el valor entero hacia abajo

print("Uso del comando ones:\n",one)
print("Uso del comando round: ",redondeo)
print("Uso del comando ceil: ",red_arr)
print("Uso del comando floor: ",red_aba)
# Out:
# Uso del comando ones:
#  [[1. 1.]
#  [1. 1.]
#  [1. 1.]]
# Uso del comando round:  16.035
# Uso del comando ceil:  17.0
# Uso del comando floor:  16.0

# %% [markdown]
# g) Acceda al valor de la primera fila, tercera columna de la matriz A, imprímalo en consola.

# %%
valor = A[0,2] # Se empieza a contar desde cero, por lo cual la primera fila es la cero y la tercera columna es la dos
print("Valor de la primera fila, tercera columna de la matriz A: ",valor)
# Out:
# Valor de la primera fila, tercera columna de la matriz A:  -3.0

# %% [markdown]
# h) Obtenga la segunda fila de dicha matriz, imprímalo en consola

# %%
segunda_fila = A[1,:] 
segunda_fila
# Out:
# array([ 4. , -1.5, -2.5])

# %% [markdown]
# i) Consulte el comando para conocer las dimensiones de una matriz, utilícelo con la matriz A e imprímalo en consola

# %%
dimensiones = A.ndim
print("Dimensiones de la matriz A: ",dimensiones)
# Out:
# Dimensiones de la matriz A:  2

# %% [markdown]
# j) Construya la función 𝑦[𝑛]=sin (𝜋∗0.18𝑛) en el intervalo 0 <= n <= 80

# %%
n = np.arange(0,80)
y = np.sin(np.pi*0.18*n)

print("Función y[n]=sin(pi*0.18n)=\n\n",y)
# Out:
# Función y[n]=sin(pi*0.18n)=
#
#  [ 0.00000000e+00  5.35826795e-01  9.04827052e-01  9.92114701e-01
#   7.70513243e-01  3.09016994e-01 -2.48689887e-01 -7.28968627e-01
#  -9.82287251e-01 -9.29776486e-01 -5.87785252e-01 -6.27905195e-02
#   4.81753674e-01  8.76306680e-01  9.98026728e-01  8.09016994e-01
#   3.68124553e-01 -1.87381315e-01 -6.84547106e-01 -9.68583161e-01
#  -9.51056516e-01 -6.37423990e-01 -1.25333234e-01  4.25779292e-01
#   8.44327926e-01  1.00000000e+00  8.44327926e-01  4.25779292e-01
#  -1.25333234e-01 -6.37423990e-01 -9.51056516e-01 -9.68583161e-01
#  -6.84547106e-01 -1.87381315e-01  3.68124553e-01  8.09016994e-01
#   9.98026728e-01  8.76306680e-01  4.81753674e-01 -6.27905195e-02
#  -5.87785252e-01 -9.29776486e-01 -9.82287251e-01 -7.28968627e-01
#  -2.48689887e-01  3.09016994e-01  7.70513243e-01  9.92114701e-01
#   9.04827052e-01  5.35826795e-01  1.10218212e-15 -5.35826795e-01
#  -9.04827052e-01 -9.92114701e-01 -7.70513243e-01 -3.09016994e-01
# ...

# %% [markdown]
# k) Construya otra senoidal 𝑦2[𝑛]=cos(2𝜋∗0.03𝑛)

# %%
n = np.arange(0,80)
y2 = np.cos(2*np.pi*0.03*n)

print ("Función y2[n]=cos(2pi*0.03n)=\n\n",y2)
# Out:
# Función y2[n]=cos(2pi*0.03n)=
#
#  [ 1.00000000e+00  9.82287251e-01  9.29776486e-01  8.44327926e-01
#   7.28968627e-01  5.87785252e-01  4.25779292e-01  2.48689887e-01
#   6.27905195e-02 -1.25333234e-01 -3.09016994e-01 -4.81753674e-01
#  -6.37423990e-01 -7.70513243e-01 -8.76306680e-01 -9.51056516e-01
#  -9.92114701e-01 -9.98026728e-01 -9.68583161e-01 -9.04827052e-01
#  -8.09016994e-01 -6.84547106e-01 -5.35826795e-01 -3.68124553e-01
#  -1.87381315e-01 -1.83697020e-16  1.87381315e-01  3.68124553e-01
#   5.35826795e-01  6.84547106e-01  8.09016994e-01  9.04827052e-01
#   9.68583161e-01  9.98026728e-01  9.92114701e-01  9.51056516e-01
#   8.76306680e-01  7.70513243e-01  6.37423990e-01  4.81753674e-01
#   3.09016994e-01  1.25333234e-01 -6.27905195e-02 -2.48689887e-01
#  -4.25779292e-01 -5.87785252e-01 -7.28968627e-01 -8.44327926e-01
#  -9.29776486e-01 -9.82287251e-01 -1.00000000e+00 -9.82287251e-01
#  -9.29776486e-01 -8.44327926e-01 -7.28968627e-01 -5.87785252e-01
# ...

# %% [markdown]
# l) Genere una tercera señal que sea la suma de estas dos señales, es decir 𝑠[𝑛]=y[n]+𝑦2[𝑛] y una cuarta, que sea el producto de estas, 𝑡[𝑛]=y[n].𝑦2[𝑛]

# %%
s = y + y2
t = y * y2
print("Suma de y[n] y y2[2]=\n",s,'\n')
print("Producto de y[n] y y2[2]=\n",t)
# Out:
# Suma de y[n] y y2[2]=
#  [ 1.          1.51811405  1.83460354  1.83644263  1.49948187  0.89680225
#   0.1770894  -0.48027874 -0.91949673 -1.05510972 -0.89680225 -0.54454419
#  -0.15567032  0.10579344  0.12172005 -0.14203952 -0.62399015 -1.18540804
#  -1.65313027 -1.87341021 -1.76007351 -1.3219711  -0.66116003  0.05765474
#   0.65694661  1.          1.03170924  0.79390384  0.41049356  0.04712312
#  -0.14203952 -0.06375611  0.28403606  0.81064541  1.36023925  1.76007351
#   1.87433341  1.64681992  1.11917766  0.41896315 -0.27876826 -0.80444325
#  -1.04507777 -0.97765851 -0.67446918 -0.27876826  0.04154462  0.14778678
#  -0.02494943 -0.44646046 -1.         -1.51811405 -1.83460354 -1.83644263
#  -1.49948187 -0.89680225 -0.1770894   0.48027874  0.91949673  1.05510972
#   0.89680225  0.54454419  0.15567032 -0.10579344 -0.12172005  0.14203952
#   0.62399015  1.18540804  1.65313027  1.87341021  1.76007351  1.3219711
#   0.66116003 -0.05765474 -0.65694661 -1.         -1.03170924 -0.79390384
# ...

# %% [markdown]
# m) Graficar en la misma figura las señales y[n] y y2[n], utilice leyenda y colores diferentes para cada señal. Asigne título a cada eje

# %%
fig, ax = plt.subplots(figsize=(5,2.7)) # Crea una figura que contiene una sola gráfica
ax.plot(y,color='lightseagreen', linestyle='--', label ='y[n]=sin(pi*0.18n)')
ax.plot(y2,color='purple', linestyle='-.', label ='y2[n]=cos(2pi*0.03n)')
ax.legend(loc = 'upper left')
ax.set_xlabel('n')
ax.set_ylabel('Amplitud')
plt.show()

# %% [markdown]
# n) Graficar en la misma figura las señales s[n] y t[n], utilice leyenda y colores diferentes para cada señal. Asigne título a cada eje

# %%
fig, ax = plt.subplots(figsize=(5,2.7)) # Crea una figura que contiene una sola gráfica
ax.plot(s,color='darkcyan', linestyle='--', label ='Suma de y[n] y y2[2]')
ax.plot(t,color='mediumvioletred', linestyle='-.', label ='Producto de y[n] y y2[2]')
ax.legend(loc = 'upper left')
ax.set_xlabel('n')
ax.set_ylabel('Amplitud')
plt.show()

# %% [markdown]
# **Reto:**
# Escribir una función que reciba un diccionario con las notas de los alumnos de un curso y devuelva una serie con la nota mínima, la máxima, media y la desviación típica.

# %%
def Reto(n):
    notas = n.values()
    notas2 = pd.Series(n)
    numeros = pd.to_numeric(notas2, errors='coerce')
    maximo = max(notas)
    minimo = min(notas)
    promedio = numeros.mean()
    redondeo = round(promedio,2)
    desviacion = numeros.std()
    redondeo_des = round(desviacion,3)
    serie = Series([maximo, minimo, redondeo, redondeo_des], index=["Maximo","Minimo","Media","Desviación Típica"])
    print(serie)

diccionario = {'Estudiante 1':'4.5','Estudiante 2': '4.0', "Estudiante 3": '4.8'}
Reto(diccionario)
# Out:
# Maximo                 4.8
# Minimo                 4.0
# Media                 4.43
# Desviación Típica    0.404
# dtype: object
